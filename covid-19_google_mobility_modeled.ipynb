# %%
dataset_id = "covid_19_google_mobility_modeled";

# %%
# !bq --location=US mk --dataset {dataset_id}
# Out:
# Dataset 'nimble-cortex-266516:covid_19_google_mobility_modeled' successfully created.

# %%
# %run covid_19_google_mobility_beam.py
# Out:
# /home/jupyter/venv/lib/python3.5/site-packages/apache_beam/io/gcp/bigquery.py:1421: BeamDeprecationWarning: options is deprecated since First stable release. References to <pipeline>.options will not be supported
#   experiments = p.options.view_as(DebugOptions).experiments or []
# INFO:apache_beam.runners.direct.direct_runner:Running pipeline with DirectRunner.
# INFO:apache_beam.io.gcp.bigquery_tools:Using location 'US' from table <TableReference
#  datasetId: 'covid_19_google_mobility_staging'
#  projectId: 'nimble-cortex-266516'
#  tableId: 'mobility_report'> referenced by query select * from covid_19_google_mobility_staging.mobility_report where country_region = "United States" and sub_region_2 is not null limit 50
# WARNING:apache_beam.io.gcp.bigquery_tools:Dataset nimble-cortex-266516:temp_dataset_59b2f5a9f072477c96c63a502b9c5b6c does not exist so we will create it as temporary with location=US
# INFO:apache_beam.io.gcp.bigquery_tools:Created table nimble-cortex-266516.covid_19_google_mobility_modeled.mobility_report_Beam with schema <TableSchema
#  fields: [<TableFieldSchema
#  fields: []
#  mode: 'NULLABLE'
#  name: 'country_region_code'
#  type: 'STRING'>, <TableFieldSchema
#  fields: []
#  mode: 'NULLABLE'
#  name: 'country_region'
#  type: 'STRING'>, <TableFieldSchema
#  fields: []
#  mode: 'NULLABLE'
#  name: 'sub_region_1'
#  type: 'STRING'>, <TableFieldSchema
#  fields: []
#  mode: 'NULLABLE'
#  name: 'sub_region_2'
#  type: 'STRING'>, <TableFieldSchema
#  fields: []
#  mode: 'NULLABLE'
#  name: 'date'
#  type: 'DATE'>, <TableFieldSchema
#  fields: []
#  mode: 'NULLABLE'
#  name: 'retail_and_recreation_percent_change_from_baseline'
#  type: 'INTEGER'>, <TableFieldSchema
#  fields: []
#  mode: 'NULLABLE'
#  name: 'grocery_and_pharmacy_percent_change_from_baseline'
#  type: 'INTEGER'>, <TableFieldSchema
#  fields: []
#  mode: 'NULLABLE'
#  name: 'parks_percent_change_from_baseline'
#  type: 'INTEGER'>, <TableFieldSchema
#  fields: []
#  mode: 'NULLABLE'
#  name: 'transit_stations_percent_change_from_baseline'
#  type: 'INTEGER'>, <TableFieldSchema
#  fields: []
#  mode: 'NULLABLE'
#  name: 'workplaces_percent_change_from_baseline'
#  type: 'INTEGER'>, <TableFieldSchema
#  fields: []
#  mode: 'NULLABLE'
#  name: 'residential_percent_change_from_baseline'
#  type: 'INTEGER'>]>. Result: <Table
#  creationTime: 1589135812695
#  etag: 'we8MSU5akmjZXrLvuSwVfw=='
#  id: 'nimble-cortex-266516:covid_19_google_mobility_modeled.mobility_report_Beam'
#  kind: 'bigquery#table'
#  lastModifiedTime: 1589135812741
#  location: 'US'
#  numBytes: 0
#  numLongTermBytes: 0
#  numRows: 0
#  schema: <TableSchema
#  fields: [<TableFieldSchema
#  fields: []
#  mode: 'NULLABLE'
#  name: 'country_region_code'
#  type: 'STRING'>, <TableFieldSchema
#  fields: []
#  mode: 'NULLABLE'
#  name: 'country_region'
#  type: 'STRING'>, <TableFieldSchema
#  fields: []
#  mode: 'NULLABLE'
#  name: 'sub_region_1'
#  type: 'STRING'>, <TableFieldSchema
#  fields: []
#  mode: 'NULLABLE'
#  name: 'sub_region_2'
#  type: 'STRING'>, <TableFieldSchema
#  fields: []
#  mode: 'NULLABLE'
#  name: 'date'
#  type: 'DATE'>, <TableFieldSchema
#  fields: []
#  mode: 'NULLABLE'
#  name: 'retail_and_recreation_percent_change_from_baseline'
#  type: 'INTEGER'>, <TableFieldSchema
#  fields: []
#  mode: 'NULLABLE'
#  name: 'grocery_and_pharmacy_percent_change_from_baseline'
#  type: 'INTEGER'>, <TableFieldSchema
#  fields: []
#  mode: 'NULLABLE'
#  name: 'parks_percent_change_from_baseline'
#  type: 'INTEGER'>, <TableFieldSchema
#  fields: []
#  mode: 'NULLABLE'
#  name: 'transit_stations_percent_change_from_baseline'
#  type: 'INTEGER'>, <TableFieldSchema
#  fields: []
#  mode: 'NULLABLE'
#  name: 'workplaces_percent_change_from_baseline'
#  type: 'INTEGER'>, <TableFieldSchema
#  fields: []
#  mode: 'NULLABLE'
#  name: 'residential_percent_change_from_baseline'
#  type: 'INTEGER'>]>
#  selfLink: 'https://www.googleapis.com/bigquery/v2/projects/nimble-cortex-266516/datasets/covid_19_google_mobility_modeled/tables/mobility_report_Beam'
#  tableReference: <TableReference
#  datasetId: 'covid_19_google_mobility_modeled'
#  projectId: 'nimble-cortex-266516'
#  tableId: 'mobility_report_Beam'>
#  type: 'TABLE'>.
# WARNING:apache_beam.io.gcp.bigquery_tools:Sleeping for 150 seconds before the write as BigQuery inserts can be routed to deleted table for 2 mins after the delete and create.

# %%
# %run covid_19_google_mobility_beam_dataflow.py
# Out:
# WARNING:apache_beam.options.pipeline_options:--region not set; will default to us-central1. Future releases of Beam will require the user to set --region explicitly, or else have a default set via the gcloud tool. https://cloud.google.com/compute/docs/regions-zones
# /home/jupyter/venv/lib/python3.5/site-packages/apache_beam/runners/dataflow/dataflow_runner.py:740: BeamDeprecationWarning: BigQuerySink is deprecated since 2.11.0. Use WriteToBigQuery instead.
#   kms_key=transform.kms_key))
# INFO:apache_beam.runners.dataflow.internal.apiclient:Starting GCS upload to gs://covid_19_cs327_extracredit-dataflow/staging/formatcountry.1589135963.605103/pipeline.pb...
# INFO:apache_beam.runners.dataflow.internal.apiclient:Completed GCS upload to gs://covid_19_cs327_extracredit-dataflow/staging/formatcountry.1589135963.605103/pipeline.pb in 0 seconds.
# INFO:apache_beam.runners.portability.stager:Downloading source distribution of the SDK from PyPi
# INFO:apache_beam.runners.portability.stager:Executing command: ['/home/jupyter/venv/bin/python', '-m', 'pip', 'download', '--dest', '/tmp/tmp_mxhiftu', 'apache-beam==2.19.0', '--no-deps', '--no-binary', ':all:']
# INFO:apache_beam.runners.portability.stager:Staging SDK sources from PyPI to gs://covid_19_cs327_extracredit-dataflow/staging/formatcountry.1589135963.605103/dataflow_python_sdk.tar
# INFO:apache_beam.runners.dataflow.internal.apiclient:Starting GCS upload to gs://covid_19_cs327_extracredit-dataflow/staging/formatcountry.1589135963.605103/dataflow_python_sdk.tar...
# INFO:apache_beam.runners.dataflow.internal.apiclient:Completed GCS upload to gs://covid_19_cs327_extracredit-dataflow/staging/formatcountry.1589135963.605103/dataflow_python_sdk.tar in 0 seconds.
# INFO:apache_beam.runners.portability.stager:Downloading binary distribution of the SDK from PyPi
# INFO:apache_beam.runners.portability.stager:Executing command: ['/home/jupyter/venv/bin/python', '-m', 'pip', 'download', '--dest', '/tmp/tmp_mxhiftu', 'apache-beam==2.19.0', '--no-deps', '--only-binary', ':all:', '--python-version', '35', '--implementation', 'cp', '--abi', 'cp35m', '--platform', 'manylinux1_x86_64']
# INFO:apache_beam.runners.portability.stager:Staging binary distribution of the SDK from PyPI to gs://covid_19_cs327_extracredit-dataflow/staging/formatcountry.1589135963.605103/apache_beam-2.19.0-cp35-cp35m-manylinux1_x86_64.whl
# INFO:apache_beam.runners.dataflow.internal.apiclient:Starting GCS upload to gs://covid_19_cs327_extracredit-dataflow/staging/formatcountry.1589135963.605103/apache_beam-2.19.0-cp35-cp35m-manylinux1_x86_64.whl...
# INFO:apache_beam.runners.dataflow.internal.apiclient:Completed GCS upload to gs://covid_19_cs327_extracredit-dataflow/staging/formatcountry.1589135963.605103/apache_beam-2.19.0-cp35-cp35m-manylinux1_x86_64.whl in 1 seconds.
# INFO:apache_beam.runners.dataflow.internal.apiclient:Create job: <Job
#  createTime: '2020-05-10T18:39:28.781550Z'
#  currentStateTime: '1970-01-01T00:00:00Z'
#  id: '2020-05-10_11_39_27-11241564689110112637'
#  location: 'us-central1'
#  name: 'formatcountry'
#  projectId: 'nimble-cortex-266516'
#  stageStates: []
#  startTime: '2020-05-10T18:39:28.781550Z'
#  steps: []
#  tempFiles: []
#  type: TypeValueValuesEnum(JOB_TYPE_BATCH, 1)>
# INFO:apache_beam.runners.dataflow.internal.apiclient:Created job with id: [2020-05-10_11_39_27-11241564689110112637]
# INFO:apache_beam.runners.dataflow.internal.apiclient:To access the Dataflow monitoring console, please navigate to https://console.cloud.google.com/dataflow/jobsDetail/locations/us-central1/jobs/2020-05-10_11_39_27-11241564689110112637?project=nimble-cortex-266516
# INFO:apache_beam.runners.dataflow.dataflow_runner:Job 2020-05-10_11_39_27-11241564689110112637 is in state JOB_STATE_PENDING
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:39:27.810Z: JOB_MESSAGE_DETAILED: Autoscaling was automatically enabled for job 2020-05-10_11_39_27-11241564689110112637.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:39:27.810Z: JOB_MESSAGE_DETAILED: Autoscaling is enabled for job 2020-05-10_11_39_27-11241564689110112637. The number of workers will be between 1 and 1000.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:39:30.744Z: JOB_MESSAGE_DETAILED: Checking permissions granted to controller Service Account.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:39:31.290Z: JOB_MESSAGE_BASIC: Worker configuration: n1-standard-4 in us-central1-a.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:39:31.879Z: JOB_MESSAGE_DETAILED: Expanding CoGroupByKey operations into optimizable parts.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:39:31.914Z: JOB_MESSAGE_DETAILED: Expanding GroupByKey operations into optimizable parts.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:39:31.947Z: JOB_MESSAGE_DETAILED: Lifting ValueCombiningMappingFns into MergeBucketsMappingFns
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:39:31.980Z: JOB_MESSAGE_DEBUG: Annotating graph with Autotuner information.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:39:32.173Z: JOB_MESSAGE_DETAILED: Fusing adjacent ParDo, Read, Write, and Flatten operations
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:39:32.203Z: JOB_MESSAGE_DETAILED: Fusing consumer Format County into Read from BigQuery
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:39:32.233Z: JOB_MESSAGE_DETAILED: Fusing consumer Write BQ table/WriteToBigQuery/NativeWrite into Format County
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:39:32.268Z: JOB_MESSAGE_DEBUG: Workflow config is missing a default resource spec.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:39:32.305Z: JOB_MESSAGE_DEBUG: Adding StepResource setup and teardown to workflow graph.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:39:32.343Z: JOB_MESSAGE_DEBUG: Adding workflow start and stop steps.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:39:32.381Z: JOB_MESSAGE_DEBUG: Assigning stage ids.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:39:32.545Z: JOB_MESSAGE_DEBUG: Executing wait step start3
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:39:32.608Z: JOB_MESSAGE_BASIC: Executing operation Read from BigQuery+Format County+Write BQ table/WriteToBigQuery/NativeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:39:32.647Z: JOB_MESSAGE_DEBUG: Starting worker pool setup.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:39:32.677Z: JOB_MESSAGE_BASIC: Starting 1 workers in us-central1-a...
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:39:34.023Z: JOB_MESSAGE_BASIC: BigQuery query issued as job: "dataflow_job_16426242831508510611". You can check its status with the bq tool: "bq show -j --project_id=nimble-cortex-266516 dataflow_job_16426242831508510611".
# INFO:apache_beam.runners.dataflow.dataflow_runner:Job 2020-05-10_11_39_27-11241564689110112637 is in state JOB_STATE_RUNNING
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:40:02.147Z: JOB_MESSAGE_DETAILED: Autoscaling: Raised the number of workers to 1 based on the rate of progress in the currently running stage(s).
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:40:42.200Z: JOB_MESSAGE_BASIC: BigQuery query completed, job : "dataflow_job_16426242831508510611"
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:40:42.607Z: JOB_MESSAGE_BASIC: BigQuery export job "dataflow_job_4388612543237607862" started. You can check its status with the bq tool: "bq show -j --project_id=nimble-cortex-266516 dataflow_job_4388612543237607862".
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:41:13.023Z: JOB_MESSAGE_DETAILED: BigQuery export job progress: "dataflow_job_4388612543237607862" observed total of 1 exported files thus far.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:41:13.054Z: JOB_MESSAGE_BASIC: BigQuery export job finished: "dataflow_job_4388612543237607862"
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:41:22.133Z: JOB_MESSAGE_DETAILED: Workers have started successfully.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:41:22.218Z: JOB_MESSAGE_DETAILED: Workers have started successfully.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:42:02.090Z: JOB_MESSAGE_BASIC: Executing BigQuery import job "dataflow_job_16426242831508512253". You can check its status with the bq tool: "bq show -j --project_id=nimble-cortex-266516 dataflow_job_16426242831508512253".
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:42:12.557Z: JOB_MESSAGE_BASIC: BigQuery import job "dataflow_job_16426242831508512253" done.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:42:13.167Z: JOB_MESSAGE_BASIC: Finished operation Read from BigQuery+Format County+Write BQ table/WriteToBigQuery/NativeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:42:13.234Z: JOB_MESSAGE_DEBUG: Executing success step success1
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:42:13.351Z: JOB_MESSAGE_DETAILED: Cleaning up.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:42:13.568Z: JOB_MESSAGE_DEBUG: Starting worker pool teardown.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:42:13.605Z: JOB_MESSAGE_BASIC: Stopping worker pool...
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:43:24.444Z: JOB_MESSAGE_DETAILED: Autoscaling: Resized worker pool from 1 to 0.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:43:24.479Z: JOB_MESSAGE_BASIC: Worker pool stopped.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2020-05-10T18:43:24.512Z: JOB_MESSAGE_DEBUG: Tearing down pending resources...
# INFO:apache_beam.runners.dataflow.dataflow_runner:Job 2020-05-10_11_39_27-11241564689110112637 is in state JOB_STATE_DONE
